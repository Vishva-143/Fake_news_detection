# %% [markdown]
# # Exploratory Data Analysis for Fake News Detection

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

train_df = pd.read_csv('dataset/train.csv')
print(train_df.head())
print(train_df.info())
print(train_df['label'].value_counts())
